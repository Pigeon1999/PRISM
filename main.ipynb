# %%
import random
import torch
import numpy as np
from types import SimpleNamespace
import data.data_loader as data_loader
import exp.exp_main as exp_main

seed = 2023
random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)

# 하이퍼파라미터 설정
config = SimpleNamespace( 
    model='PRISM',   # DMSLinear, SegTSF, PRISM
    dataset="ETTh1.csv", # ETTh1, ETTh2, ETTm1, ETTm2, traffic, electricity, weather, Solar, exchange_rate
    seq_len=720,
    pred_len=96,
    channels=7,
    batch_size=64, 
    learning_rate=0.02,                              
    lradj='type3', 
    epochs=30,               
    patience=5,
    criterion='MSE',
    
    #############
    # DMSLinear # 
    ##########################################################################
    # 하이퍼 파라미터 설정 없음
    ##########################################################################
    
    ##########
    # SegTSF # 
    ##########################################################################
    # period_len=24,
    # seg_len_x=1, 
    # seg_len_y=1, 
    ##########################################################################
    
    #########
    # PRISM #
    ##########################################################################
    period_len=24,
    kernel_size=14,
    stride=16,
    dilation=1,
    temporal_kernel_size=23,
    ##########################################################################
)

train_dataset, train_loader, test_dataset, test_loader, vali_dataset, vali_loader = data_loader.data_provider(config)
model = exp_main.train(config, train_loader, vali_loader, test_loader) 
exp_main.test(config, test_dataset, test_loader, model)
# Out:
# Model total parameters: 45
# Computational complexity: 13.78 KMac
# Number of parameters: 45
# 	iters: 100, epoch: 1 | loss: 0.5852422
# 	speed: 0.0000s/iter; left time: 0.0116s
# Epoch: 1 cost time: 1.2191221714019775
# Epoch: 1, Steps: 122 | Train Loss: 0.6174284 Vali Loss: 1.2833753 Test Loss: 0.7023901
# Validation loss decreased (inf --> 1.283375).  Saving model ...
# Updating learning rate to 0.02
# ...
# Max Memory (MB): 23.82080078125
# 	iters: 100, epoch: 2 | loss: 0.3171725
# 	speed: 0.0000s/iter; left time: 0.0108s
# Epoch: 2 cost time: 1.2236733436584473
# Epoch: 2, Steps: 122 | Train Loss: 0.3823767 Vali Loss: 0.7189197 Test Loss: 0.3539158
# Validation loss decreased (1.283375 --> 0.718920).  Saving model ...
# Updating learning rate to 0.02
# ...
# Max Memory (MB): 26.013671875
# 	iters: 100, epoch: 3 | loss: 0.3535641
# 	speed: 0.0000s/iter; left time: 0.0092s
# Epoch: 3 cost time: 1.3126897811889648
# ...
